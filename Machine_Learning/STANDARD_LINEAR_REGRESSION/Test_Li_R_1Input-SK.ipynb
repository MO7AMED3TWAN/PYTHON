# %%
#### IMPORTING LIBRARIES ####
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
#### READ DATA ####
path = r"test1.csv "
data = pd.read_csv(path)

# %% [markdown]
# # DEFINE DATA

# %%
#### define features and target and Theta ####

X=data.iloc[:,:-1]
y=data.iloc[:,-1]
    
# data.columns=['','','','','',...]#تعريف اسماء الاعمدة 

#### SPLITTING DATA ####
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %% [markdown]
# # SHOWING DATA

# %%
print(f"That's Information About My Data \n{data.info()}\n\n")

print(f"That's My First 5 Rows IN My Data \n{data.head()}\n\n")

print(f"That's The Describtion Of My Data \n{data.describe()}\n\n")

print(f"SCATTER OF MY DATA \n{plt.scatter(data.X,data.Y ,c='r' )}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       70 non-null     float64
#  1   Y       70 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB
# That's Information About My Data
# None
#
#
# That's My First 5 Rows IN My Data
#          X        Y
# 0  10.9570   7.0467
# 1  13.1760  14.6920
# 2  22.2030  24.1470
# 3   5.2524  -1.2200
# 4   6.5894   5.9966
#
#
# That's The Describtion Of My Data
#                X          Y
# count  70.000000  70.000000
# mean    8.240810   4.954765
# std     3.847999   5.028818
# min     5.026900  -2.680700
# 25%     5.713075   1.527375
# 50%     7.155650   4.265000
# 75%     9.231200   6.718825
# max    22.203000  24.147000
#
#
# SCATTER OF MY DATA
# <matplotlib.collections.PathCollection object at 0x000001B8C02345D0>

# %% [markdown]
# # This Step To Scalling The Data (You Can Skip It If Your Data Is OK)

# %% [markdown]
# # DRAWING BEST FIT LINE

# %%
sns.regplot(x='X',y='Y',data=data,marker='+')
# Out:
# <AxesSubplot: xlabel='X', ylabel='Y'>

# %% [markdown]
# # CREATE A MODEL OF PREDECTION

# %%
### MAKING MODEL ###
L_G_MODEL=LinearRegression()

### TRAINING MODEL ###
L_G_MODEL.fit(X_train,y_train)

### PREDECT BY MODEL ###
Predect_Values=L_G_MODEL.predict(X_test)

# %% [markdown]
# ## DRAW SCATTER OF RESULTS

# %%
#Draw Scatter
fig, shape = plt.subplots(figsize=(5,5))
shape.scatter(X_train,y_train,c='b'        , label='Original Data')
shape.scatter(X_test,Predect_Values,c='r', label='Prediction')
shape.legend(loc=0)
#describ the shape
shape.set_xlabel('X')
shape.set_ylabel('Y & Predect')
shape.set_title('MY ORIGINAL & PREDECT DATA')
plt.show()

# %% [markdown]
# ## The Coefficients

# %%
print("Coefficients: \n", L_G_MODEL.coef_)
# Out:
# Coefficients:
#  [1.10240759]

# %% [markdown]
# # SCORE OF ERROR

# %%
#Import Libraries
from sklearn.metrics import mean_squared_error 
#----------------------------------------------------
#Calculating Mean Squared Error
MSEValue = mean_squared_error(y_test, Predect_Values) # it can be raw_values
print('Mean Squared Error Value is : ',round(MSEValue,4))
# Out:
# Mean Squared Error Value is :  4.7046

# %%
#Import Libraries
from sklearn.metrics import r2_score
#----------------------------------------------------
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test,Predect_Values))
# Out:
# Coefficient of determination: 0.89

# %% [markdown]
# # THE END
